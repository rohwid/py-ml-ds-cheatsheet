# %%
import pandas as pd

# %%
df = pd.read_csv('input/raw_clean_header.txt', header=None, delim_whitespace=True)

# %%
df = df.iloc[0:25, :]
df
# Out:
#           0      1
# 0    Daftar      O
# 1   Profesi      O
# 2      Yang      O
# 3      Siap      O
# 4     Kerja      O
# 5      dari      O
# 6     Rumah      O
# 7     Versi      O
# 8      Anji  B-PER
# 9   JAKARTA      O
# 10        -      O
# 11     Anji  B-PER
# 12  membuat      O
# 13   daftar      O
# 14    orang      O
# 15     yang      O
# 16     siap      O
# 17  bekerja      O
# 18     dari      O
# 19    rumah      O
# 20        .      O
# 21       Di      O
# 22     mana      O
# 23     saat      O
# 24      ini      O

# %%
df.to_csv('output/raw_wo_header.txt', index=None, header=None, sep='\t')

# %%
df = pd.read_csv('input/tab_separated_data.tsv', sep='\t')

df
# Out:
#                       word_x                                           word_y  \
# 0           Kementerian BUMN                         Badan Pengatur Jalan Tol
# 1           Kementerian BUMN                                             BPJT
# 2           Kementerian BUMN  Kementerian Pekerjaan Umum dan Perumahan Rakyat
# 3           Kementerian BUMN                    PT Jasa Marga ( Persero ) Tbk
# 4           Kementerian BUMN             PT Citra Marga Nusaphala Persada Tbk
# 5           Kementerian BUMN                                             BUMN
# 6           Kementerian BUMN                                       Jasa Marga
# 7           Kementerian BUMN                                             BUMN
# 8           Kementerian BUMN                         Badan Pengatur Jalan Tol
# 9           Kementerian BUMN                                 Kementerian PUPR
# 10          Kementerian BUMN                            Badan Usaha Jalan Tol
# ...

# %%
df.to_csv('output/tab_separated_data_wo_header.tsv', index=None, sep='\t')
